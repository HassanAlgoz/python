# %% [raw]
# ---
# title: "حل مسائل التغليف والتعميم وإعادة الهيكلة"
# og:title: encapsulation_generalization_refactoring_solutions
# toc: true
# format:
#   html: default
#   ipynb: default
# ---

# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HassanAlgoz/python/blob/main/book/exercises/03b_composition/solutions.ipynb)

# %% [markdown]
# لتكون المسائل قريبة من الحسّ والبصر، سنستخدم مكتبة [`jupyturtle`](https://pypi.org/project/jupyturtle/) كما في دفتر التطبيقات.
#
# **التهيئة:** ثبّت الحزمة إن لزم، ثم نفّذ خلية الاستيراد التالية قبل الحلول.
#
# بعد كل تمرين (حيث يظهر عنوان **اختبار مرئي**) نفّذ الخلية البرمجية التالية لترى النتيجة.

# %% [markdown]
# ```sh
# uv add jupyturtle
# ```

# %%
import math
from jupyturtle import (
    Turtle,
    make_turtle,
)

# %% [markdown]
# المتغير `delay` يتم تمريره للتحكم بسرعة الرسم:

# %%
# Control speed of drawing
fps = 10
delay = 1 / fps

# %% [markdown]
# ## 1. رسم مستطيل
#
# الفكرة: استخدم حلقة وانعطافات السلحفاة لتتبّع محيط المستطيل.
#
# **المطلوب:** نفّذ الدالة `rectangle(t, width, height)` لترسم مستطيلًا بالأطوال المعطاة.

# %%
def rectangle(t: Turtle, width: float, height: float) -> None:
    for _ in range(2):
        t.forward(width)
        t.left(90)
        t.forward(height)
        t.left(90)

# %% [markdown]
# **اختبار مرئي:** نفّذ الخلية التالية بعد إكمال `rectangle`.

# %%
t = make_turtle(delay=delay)
rectangle(t, 80, 40)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 230,75 230,35 150,35 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## 2. رسم معين
#
# الفكرة: المَعِين يُرسم بمدّ متعاقبة مع زاويتي انعطاف متكاملتين (تكملان 180°).
#
# **المطلوب:** نفّذ الدالة `rhombus(t, length, angle)` لترسم معينًا بطول ضلع `length` وزاوية داخلية `angle` (بالدرجات).

# %%
def rhombus(t: Turtle, length: float, angle: float) -> None:
    second_angle = 180 - angle
    for _ in range(2):
        t.forward(length)
        t.left(angle)
        t.forward(length)
        t.left(second_angle)

# %% [markdown]
# **اختبار مرئي:** نفّذ الخلية التالية بعد إكمال `rhombus`.

# %%
t = make_turtle(delay=delay)
rhombus(t, 70, 60)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 220,75 255,14.4 185,14.4 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## 3. تعميم بمتوازي أضلاع
#
# الفكرة: أعد استخدام منطق الرسم المشترك بين أشكال متعددة.
#
# **المطلوب:** نفّذ `parallelogram(t, side1, side2, angle)`، ثم أعد كتابة `rectangle` و`rhombus` بحيث تستدعيان `parallelogram` (المستطيل معين بزاوية 90°، والمعين بضلعين متساويين).

# %%
def parallelogram(t: Turtle, side1: float, side2: float, angle: float) -> None:
    second_angle = 180 - angle
    for _ in range(2):
        t.forward(side1)
        t.left(angle)
        t.forward(side2)
        t.left(second_angle)


def rectangle(t: Turtle, width: float, height: float) -> None:
    parallelogram(t, width, height, 90)


def rhombus(t: Turtle, length: float, angle: float) -> None:
    parallelogram(t, length, length, angle)

# %% [markdown]
# **اختبار مرئي:** مستطيل، ثم معين، ثم متوازي أضلاع عام — بعد إكمال التعريفات الثلاثة.

# %%
t = make_turtle(delay=delay, width=400)

t.pen_up()
t.forward(-120)
t.pen_down()
rectangle(t, 80, 40)

t.pen_up()
t.forward(100)
t.pen_down()
rhombus(t, 50, 60)

t.pen_up()
t.forward(80)
t.pen_down()
parallelogram(t, 80, 50, 60)
# Out:
# <svg width="400" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 80,75 160,75 160,35 80,35 80,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 230,75 255,31.7 205,31.7 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 260,75 340,75 365,31.7 285,31.7 260,75" />'
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## 4. دالة القفز `jump`
#
# الفكرة: اجمع تسلسلًا متكررًا من أوامر السلحفاة في دالة واحدة.
#
# **المطلوب:** اكتب الدالة `jump(t, length)` التي تنفّذ بالترتيب: `pen_up()` ثم `forward(length)` ثم `pen_down()` — بحيث تتحرك بمسافة `length` دون رسم، وتنتهي والقلم للأسفل.
#
# يمكنك بعدها استخدام `jump` لفصل أشكال متجاورة بدل تكرار الثلاثة أوامر.

# %%
def jump(t: Turtle, length: float) -> None:
    t.pen_up()
    t.forward(length)
    t.pen_down()

# %% [markdown]
# **اختبار مرئي:** نفس الأشكال السابقة باستخدام `jump` بدل تكرار `pen_up` / `pen_down`.

# %%
t = make_turtle(
    delay=delay,
    width=400,
)

jump(t, -120)
rectangle(t, 80, 40)

jump(t, 100)
rhombus(t, 50, 60)

jump(t, 80)
parallelogram(t, 80, 50, 60)
# Out:
# <svg width="400" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 80,75 160,75 160,35 80,35 80,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 230,75 255,31.7 205,31.7 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 260,75 340,75 365,31.7 285,31.7 260,75" />'
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## 5. «فطيرة» من مثلثات متكررة
#
# الفكرة: ابنِ شكلًا أكبر بتكرار أداة رسم صغيرة (قطعة مثلثية).
#
# **المطلوب:**
#
# 1. نفّذ `triangle(t, r, angle)` لترسم قطعة مثلثية واحدة (كما في النص الأصلي للفصل).
# 2. نفّذ `draw_pie(t, n, r)` لتكرار هذه القطعة `n` مرّة وتكوين فطيرة كاملة.

# %%
def triangle(t: Turtle, r: float, angle: float) -> None:
    side = 2 * r * math.sin(math.radians(angle) / 2)
    base_angle = (180 - angle) / 2
    t.forward(r)
    t.left(180 - base_angle)
    t.forward(side)
    t.left(180 - base_angle)
    t.forward(r)


def draw_pie(t: Turtle, n: int, r: float) -> None:
    angle = 360 / n
    for _ in range(n):
        triangle(t, r, angle)
        t.left(angle)

# %% [markdown]
# **اختبار مرئي (مثلث واحد):** نُسرّع الرسم بقيمة `delay` أصغر.

# %%
tri_fps = 40
tri_delay = 1 / tri_fps
t_tri = make_turtle(delay=tri_delay)
triangle(t_tri, 60, 20)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 210,75 206.4,54.5 150,75" />'
#
# <g transform="rotate(70.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# **اختبار مرئي (فطائر):** ثلاث فطائر بأعداد أضلاع مختلفة؛ يفترض أن تكون `jump` قد عرّفتَها في التمرين السابق.

# %%
size = 40
margin = 2 * size + 20

t = make_turtle(
    delay=delay,
    width=50 + (size + margin) * 3,
)

t.pen_up()
t.forward(-80)
t.pen_down()

draw_pie(t, 5, size)

jump(t, margin)
draw_pie(t, 6, size)

jump(t, margin)
draw_pie(t, 7, size)
# Out:
# <svg width="470" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 235,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 155,75 195,75 167.4,37 155,75 187.4,98.5 187.4,51.5 155,75 167.4,113 195,75 155,75 142.6,113 187.4,98.5 155,75 122.6,98.5 167.4,113 155,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 55,75 15,75 35,109.6 55,75 35,40.4 15,75 55,75 75,40.4 35,40.4 55,75 95,75 75,40.4 55,75 75,109.6 95,75 55,75 35,109.6 75,109.6 55,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M -45,75 -85,75 -69.9,106.3 -45,75 -53.9,36 -81,57.6 -45,75 -9,57.6 -36.1,36 -45,75 -20.1,106.3 -5,75 -45,75 -69.9,106.3 -36.1,114 -45,75 -81,57.6 -81,92.4 -45,75 -36.1,36 -69.9,43.7 -45,75" />'
#
# <g transform="rotate(270.0,-45.0,75.0) translate(-45.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
# ...

# %% [markdown]
# ## 6. زهرة بأوراق
#
# الفكرة: اجمع زهرة كاملة بتكرار رسم ورقة واحدة.
#
# **المطلوب:** باستخدام الدالة `arc` المعطاة في الخلية التالية، نفّذ `petal(t, r, angle)` لرسم ورقة واحدة، ثم `flower(t, n, r, angle)` لتجميع `n` ورقة في زهرة.

# %%
def arc(t: Turtle, r: float, angle: float) -> None:
    for i in range(r):
        t.forward(r, i * 2)

# %% [markdown]
# **اختبار مرئي:** الدالة `arc` المعطاة (مرجع قبل رسم الورقة).

# %%
t = make_turtle(delay=delay)
arc(t, 10, 36)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 160,75 170,75 180,74.7 189.9,73.6 199.7,71.5 209.1,68.1 217.8,63.1 225.2,56.4 230.8,48.1 233.9,38.6" />'
#
# <g transform="rotate(180.0,233.9,38.6) translate(233.9, 38.6)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def petal(t: Turtle, r: float, angle: float) -> None:
    arc(t, r, angle)
    t.left(90)
    arc(t, r, angle)


def flower(t: Turtle, n: int, r: float, angle: float) -> None:
    for _ in range(n):
        petal(t, r, angle)
        t.left(360 / n)

# %% [markdown]
# **اختبار مرئي:** ورقة واحدة بـ `petal`.

# %%
t = make_turtle(delay=delay)
petal(t, 10, 36)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 160,75 170,75 180,74.7 189.9,73.6 199.7,71.5 209.1,68.1 217.8,63.1 225.2,56.4 230.8,48.1 233.9,38.6 223.9,38.6 213.9,38.6 203.9,39 194,40 184.2,42.1 174.8,45.5 166.1,50.5 158.7,57.2 153.1,65.5 150,75" />'
#
# <g transform="rotate(0.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# **اختبار مرئي:** زهرة كاملة؛ لوحة أكبر كما في دفتر الفصل.

# %%
t = make_turtle(
    delay=delay / 10,
    height=400,
    width=400,
)
flower(t, 8, 10, 36)
# Out:
# <svg width="400" height="400" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# ...

# %% [markdown]
# ## 7. حلزون
#
# البرنامج التالي (من نفس الفصل) يوضّح رسم مضلّع ودائرة تقريبية باستخدام السلحفاة — اقرأه كسياق، ثم انتقل للمطلوب.
#
# **المطلوب:** اكتب الدالة `spiral(t, n, length, gap)` التي ترسم حلزونًا: في كل خطوة تمشي `length` ثم تنعطف بزاوية ثابتة، وتزيد `length` بمقدار `gap` للخطوة التالية (كرر `n` مرّة).

# %%
def polygon(t: Turtle, n: int, length: float) -> None:
    angle = 360 / n
    for i in range(n):
        t.forward(length)
        t.left(angle)


def circle(t: Turtle, radius: float) -> None:
    circumference = 2 * math.pi * radius
    n = 10
    length = circumference / n
    polygon(t, n, length)


# مثال: t = make_turtle(delay=delay); t.jump_to(120, 120); circle(t, 60)

# %% [markdown]
# **اختبار مرئي (اختياري):** دائرة تقريبية باستخدام `polygon` و`circle` من خلية السياق.

# %%
t = make_turtle(delay=delay / 10)
t.jump_to(120, 120)
circle(t, 60)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 120,120 157.7,120 188.2,97.8 199.8,62 188.2,26.1 157.7,4 120,4 89.5,26.1 77.9,62 89.5,97.8 120,120" />'
#
# <g transform="rotate(-90.0,120.0,120.0) translate(120.0, 120.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def spiral(t: Turtle, n: int, length: float, gap: float) -> None:
    angle = 360 / 20
    for _ in range(n):
        t.forward(length)
        t.left(angle)
        length = length + gap

# %% [markdown]
# **اختبار مرئي:** الحلزون بعد إكمال `spiral`.

# %%
t = make_turtle(delay=delay / 10)
spiral(t, 50, 5, 0.2)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 155,75 159.9,73.4 164.3,70.2 167.6,65.7 169.4,60.2 169.4,54.2 167.5,48.3 163.7,43.1 158.4,39.2 151.9,37.1 144.9,37.1 138.1,39.3 132.1,43.7 127.6,49.8 125.2,57.3 125.2,65.3 127.7,73.1 132.7,79.9 139.6,84.9 148,87.6 157,87.6 165.7,84.8 173.4,79.3 179,71.5 182,62.2 182,52.2 178.9,42.5 172.8,34.1 164.2,27.8 153.9,24.5 142.9,24.5 132.3,28 123,34.7 116.2,44 112.6,55.3 112.6,67.3 116.3,78.9 123.6,88.9 133.8,96.3 146,100.3 159,100.3 171.6,96.2 182.4,88.3 190.4,77.3 194.7,64.2 194.7,50.2 190.3,36.7 181.8,25 170,16.4 155.9,11.9" />'
#
# <g transform="rotate(90.0,155.9,11.9) translate(155.9, 11.9)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
