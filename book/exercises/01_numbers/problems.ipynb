# %% [raw]
# ---
# title: "مسائل في الأرقام"
# og:title: numbers_problems
# toc: true
# format:
#   html: default
#   ipynb: default
# ---

# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HassanAlgoz/python/blob/main/book/exercises/01_numbers/problems.ipynb)

# %% [markdown]
# ## 1. كم سيكون عمرك حين كذا؟
#
# 1. عرف تاريخ الحدث المستقبلي بالسنوات: `future_date`
# 2. عرف تاريخ اليوم: `today`
# 3. عرف المتغير: `age`
# 4. احسب عمرك عند حصول الحدث: `age_then`
# 5. اطبع النتيجة: `print(age_then)`

# %%
# CODE HERE

# %% [markdown]
# ## 2. حساب الأجر
#
# 1. عدد ساعات العمل: `hours`
# 2. معدل الأجر لكل ساعة: `per_hour_rate`
# 3. احسب الأجر الذي تستحقه بناءً على عدد الساعات ومعدل الأجر: `gross_pay`
# 4. اطبع النتيجة: `print(gross_pay)`

# %%
# CODE HERE

# %% [markdown]
# ## 3. حساب الزمن المستغرق للوصول إلى مكان معيَّن
#
# 1. سرعة السيارة: `speed`
# 2. المسافة: `distance`
# 3. احسب الزمن المستغرق للوصول إلى المكان المعيَّن بناءً على السرعة والمسافة: `time`
# 4. اطبع النتيجة: `print(time)`

# %%
# CODE HERE

# %% [markdown]
# ## 4. حساب ارتفاع المثلث عن طريق أطوال أضلاعه
#
# ![مثلث](../../assets/triangle.png)
#
# باستخدام **معادلة هيرون**:
#
# $$
# \text{area} = \sqrt{s (s - a) (s - b) (s - c)}
# $$
#
# حيث:
#
# - $a$, $b$, $c$ هي أطوال أضلاع المثلث
# - نصف المحيط:
#
# $$
# s = \frac{a + b + c}{2}
# $$

# %%
a, b, c = 3, 4, 5

# %%
# CODE HERE

# %% [markdown]
# ## 5. استخدام الصيغ الرياضية
#
# الفكرة الأساسية: استخدم المتغيِّرات ودوال مكتبة `math` لتحويل الصيغ الرياضية إلى بايثون.

# %%
import math

# %% [markdown]
# المطلوب:
#
# 1. حجم الكرة — إذا كان نصف القطر `radius = 5`، احسب حجم الكرة، خزِّن الناتج في متغير `volume`، واطبع النتيجة.
# 2. متطابقة مثلثية — عيِّن `x = 42`، احسب القيمة `math.cos(x)**2 + math.sin(x)**2`، واطبع الناتج.
# 3. قوى العدد $e$ — احسب $e^2$ باستخدام `math.e**2`، و `math.pow(math.e, 2)`، و `math.exp(2)`، واطبع القيم الثلاثة للمقارنة.

# %%
# CODE HERE

# %% [markdown]
# ## 5. نسبة التغير
#
# إذا كنت تصرف في الشهر 1,000 ريال لقضاء حاجياتك، ثم اتبعت استراتيجية معينة، وأردت أن تحسب نسبة التغير في مصروفك، فكيف تعرف النسبة إذا نزلت إلى 650 ريال؟

# %%
# CODE HERE

# %% [markdown]
# ## 6. التغير النسبي
#
# إذا كنت تمارس الرياضة وتزيد في وزن الحمل 10% أسبوعيًّا .. فإذا بدأت بوزن 20 كيلو، فإلى كم كيلوا ستصل في الأسبوع الرابع؟
#
# مساعدة: فكك العبارة واجعلها في متغيرات، وضع لكل أسبوعٍ متغيِّرًا يعتمد على الأسبوع الذي قبله.

# %%
# CODE HERE

# %% [markdown]
# ## 7. الفرق بين النوع العددي والنوع النصي للعدد
#
# إذا كان عندك هذه المتغيرات الثلاثة، فكيف تقيم عملية الجمع بالشكل الصحيح؟ (أولاً: استعمل `type` لمعرفة نوع كل متغير)

# %%
a = 4
b = 3.14
c = "10"

# %%
# CODE HERE
