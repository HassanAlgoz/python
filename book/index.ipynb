# %% [markdown]
# ---
# title: "فهرس"
# og:title: index
# ---
#
# # فهرس
#
# - [المقدمة](chapters/00_rewrite/00_intro.qmd)
# - [النص البرمجي](chapters/00_rewrite/01_instructions.ipynb)
# - [التحكم في التدفق](chapters/00_rewrite/02_control_flow.ipynb)
# - [الوظائف](chapters/00_rewrite/03_functions.ipynb)
# - [المتسلسلات](chapters/00_rewrite/04_sequences.ipynb)
# - [الكمبيوتر والعالم](chapters/00_rewrite/05_computer_and_world.ipynb)
# - [الملفات النصية](chapters/00_rewrite/06_text_files.ipynb)
# - [المتكررات](chapters/00_rewrite/07_iterators.ipynb)
# - [الكائنات](chapters/00_rewrite/09_oop.ipynb)
# - [الوظائف الدالية](chapters/00_rewrite/10_functional.ipynb)
# - [الأخطاء](chapters/00_rewrite/11_errors.ipynb)
